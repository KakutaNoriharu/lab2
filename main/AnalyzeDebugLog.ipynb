# %%
r=1.3
p=1
for i in range(20):
    p=p*r-p*0.2
    print(i,p)
# Out:
# 0 1.1
# 1 1.2100000000000002
# 2 1.3310000000000004
# 3 1.4641000000000006
# 4 1.6105100000000008
# 5 1.771561000000001
# 6 1.948717100000001
# 7 2.143588810000001
# 8 2.3579476910000015
# 9 2.5937424601000014
# 10 2.8531167061100016
# 11 3.1384283767210017
# 12 3.452271214393102
# 13 3.7974983358324126
# 14 4.177248169415654
# 15 4.594972986357219
# 16 5.0544702849929415
# 17 5.559917313492235
# 18 6.115909044841459
# 19 6.727499949325605

# %%
500000*190
# Out:
# 95000000
